# %%
import matplotlib.pyplot as plt
from keras.src.layers import LSTM
from plot_keras_history import plot_history

from study.a_rec import ActivityRecognitionModel
from util.vis import get_model_vis
# Out:
# 2024-06-13 22:24:12.794283: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = ActivityRecognitionModel(segment_size=50, batch_size=200, n_shifts=4)

model.add_input_layer()
model.add(LSTM(700, activation="tanh"))
model.add_output_layer()

model.compile(
    optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)

get_model_vis(model)
# Out:
# 2024-06-13 22:24:15.613177: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-13 22:24:15.619666: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-13 22:24:15.619728: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-13 22:24:15.624760: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-13 22:24:15.624824: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-13 22:24:15.624854: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-13 22:24:15.797581: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-13 22:24:15.797644: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-13 22:24:15.797655: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-06-13 22:24:15.797755: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-13 22:24:15.797790: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2246 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:08:00.0, compute capability: 7.5

# %%
history = model.train_model()
plt.show(plot_history(history))
# Out:
# Epoch 1/20
# 2024-06-13 22:24:18.660109: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 19s 163ms/step - accuracy: 0.6519 - loss: 1.0610 - val_accuracy: 0.8832 - val_loss: 0.5023
# Epoch 2/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 16s 150ms/step - accuracy: 0.9225 - loss: 0.2325 - val_accuracy: 0.8864 - val_loss: 0.4286
# Epoch 3/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 16s 151ms/step - accuracy: 0.9720 - loss: 0.0977 - val_accuracy: 0.9018 - val_loss: 0.4012
# Epoch 4/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 15s 141ms/step - accuracy: 0.9710 - loss: 0.0764 - val_accuracy: 0.9164 - val_loss: 0.3268
# Epoch 5/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 15s 143ms/step - accuracy: 0.9768 - loss: 0.0847 - val_accuracy: 0.9179 - val_loss: 0.3157
# Epoch 6/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 15s 143ms/step - accuracy: 0.9931 - loss: 0.0233 - val_accuracy: 0.9279 - val_loss: 0.2518
# Epoch 7/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 16s 152ms/step - accuracy: 0.9972 - loss: 0.0113 - val_accuracy: 0.8282 - val_loss: 0.5068
# Epoch 8/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 15s 141ms/step - accuracy: 0.9986 - loss: 0.0064 - val_accuracy: 0.9082 - val_loss: 0.3997

# %%
model.evaluate_model()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - accuracy: 0.9470 - loss: 0.1644
# Loss: 0.1735, Accuracy: 0.9538
