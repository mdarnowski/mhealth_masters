# %%
from study.a_rec import ActivityRecognitionModel

# %%
from keras.src.layers import GRU

from util import vis

# %%
model = ActivityRecognitionModel(
    segment_size=50,
    batch_size=100,
    n_shifts=1,
    epochs=15,
    l_rate=0.001,
    optimizer_name="adam",
)

model.add_input_layer()
model.add(GRU(128))
model.add_output_layer()

model.compile_model()

vis.get_model_vis(model)

# %%
history = model.train_model()
# Out:
# Epoch 1/15
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - loss: 1.9482 - sparse_categorical_accuracy: 0.4206 - sparse_top_3_accuracy: 0.6223 - val_loss: 0.8811 - val_sparse_categorical_accuracy: 0.7214 - val_sparse_top_3_accuracy: 0.9186
# Epoch 2/15
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 171ms/step - loss: 0.6388 - sparse_categorical_accuracy: 0.8311 - sparse_top_3_accuracy: 0.9711 - val_loss: 0.5445 - val_sparse_categorical_accuracy: 0.8071 - val_sparse_top_3_accuracy: 0.9743
# Epoch 3/15
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - loss: 0.3501 - sparse_categorical_accuracy: 0.9146 - sparse_top_3_accuracy: 0.9921 - val_loss: 0.4133 - val_sparse_categorical_accuracy: 0.8514 - val_sparse_top_3_accuracy: 0.9871
# Epoch 4/15
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 8s 157ms/step - loss: 0.2325 - sparse_categorical_accuracy: 0.9489 - sparse_top_3_accuracy: 0.9956 - val_loss: 0.3610 - val_sparse_categorical_accuracy: 0.8643 - val_sparse_top_3_accuracy: 0.9900
# Epoch 5/15
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - loss: 0.1666 - sparse_categorical_accuracy: 0.9682 - sparse_top_3_accuracy: 0.9990 - val_loss: 0.3388 - val_sparse_categorical_accuracy: 0.8686 - val_sparse_top_3_accuracy: 0.9914
# Epoch 6/15
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 169ms/step - loss: 0.1196 - sparse_categorical_accuracy: 0.9806 - sparse_top_3_accuracy: 0.9989 - val_loss: 0.3108 - val_sparse_categorical_accuracy: 0.8871 - val_sparse_top_3_accuracy: 0.9957
# Epoch 7/15
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 166ms/step - loss: 0.0878 - sparse_categorical_accuracy: 0.9852 - sparse_top_3_accuracy: 0.9997 - val_loss: 0.3130 - val_sparse_categorical_accuracy: 0.8943 - val_sparse_top_3_accuracy: 0.9943
# Epoch 8/15
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 172ms/step - loss: 0.0699 - sparse_categorical_accuracy: 0.9895 - sparse_top_3_accuracy: 1.0000 - val_loss: 0.3308 - val_sparse_categorical_accuracy: 0.8814 - val_sparse_top_3_accuracy: 0.9929

# %%
vis.plot_val_history(history)

# %%
vis.plot_evaluation_results(model)
